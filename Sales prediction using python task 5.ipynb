# %% [markdown]
# Sales Prediction Using Python

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
#import the given dataset
df = pd.read_csv(r"C:\Users\Alekhya\Downloads\archive (3)\Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.shape
# Out:
# (200, 5)

# %%
#exploring the above dataset
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
#check for null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# Data Visualization

# %%
sns.pairplot(df, x_vars=["TV","Radio","Newspaper"], y_vars="Sales", kind="scatter")
plt.show()

# %% [markdown]
# Observation include when TV adversing is increased sales are also increasing

# %%
plt.style.use("seaborn-whitegrid")
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# C:\Users\Alekhya\AppData\Local\Temp\ipykernel_28216\1122648781.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %%
X=df.TV
X
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV, Length: 200, dtype: float64

# %%
Y=df.Sales
Y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# Model using Linear Regression

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(df[["TV"]],df[['Sales']],test_size =0.3)

# %%
print(x_test)
# Out:
#         TV
# 18    69.2
# 89   109.8
# 93   250.9
# 96   197.6
# 29    70.6
# 16    67.8
# 62   239.3
# 65    69.0
# 178  276.7
# 160  172.5
# 185  205.0
# 53   182.6
# 115   75.1
# 123  123.1
# 71   109.8
# 147  243.2
# 155    4.1
# 174  222.4
# 84   213.5
# 144   96.2
# 36   266.9
# 7    120.2
# 146  240.1
# 176  248.4
# 114   78.2
# 153  171.3
# 128  220.3
# 193  166.8
# 22    13.2
# 27   240.1
# 49    66.9
# 23   228.3
# 39   228.0
# 157  149.8
# 94   107.4
# 73   129.4
# 166   17.9
# 104  238.2
# 91    28.6
# 181  218.5
# 154  187.8
# 55   198.9
# 182   56.2
# 99   135.2
# 98   289.7
# 44    25.1
# 68   237.4
# 137  273.7
# 117   76.4
# 196   94.2
# 132    8.4
# 43   206.9
# 110  225.8
# 40   202.5
# 126    7.8
# 195   38.2
# 79   116.0
# 20   218.4
# 10    66.1
# 11   214.7

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.predict(x_test))
# Out:
# [[10.37661275]
#  [12.21878498]
#  [18.6210141 ]
#  [16.20259587]
#  [10.44013593]
#  [10.31308957]
#  [18.09467918]
#  [10.36753801]
#  [19.79165557]
#  [15.06371599]
#  [16.53836126]
#  [15.52199037]
#  [10.64431758]
#  [12.8222552 ]
#  [12.21878498]
#  [18.27163661]
#  [ 7.42278486]
#  [17.32786364]
#  [16.92403771]
#  [11.60170266]
#  [19.34699331]
#  [12.69067147]
#  [18.13097814]
#  [18.50757985]
#  [10.78497605]
#  [15.00926755]
#  [17.23257887]
#  [14.8050859 ]
#  [ 7.83568553]
#  [18.13097814]
#  [10.27225324]
#  [17.59556847]
#  [17.58195636]
#  [14.033733  ]
#  [12.1098881 ]
#  [13.10810951]
#  [ 8.04894192]
#  [18.04476811]
#  [ 8.53444051]
#  [17.15090621]
#  [15.75793361]
#  [16.26158168]
#  [ 9.78675464]
#  [13.37127697]
#  [20.38151368]
#  [ 8.37563256]
#  [18.00846915]
#  [19.65553447]
#  [10.70330339]
#  [11.51095526]
#  [ 7.61789177]
#  [16.62457129]
#  [17.48213422]
#  [16.424927  ]
#  [ 7.59066755]
#  [ 8.97002804]
#  [12.50010192]
#  [17.14636884]
# ...

# %%
model.coef_
# Out:
# array([[0.0453737]])

# %%
model.intercept_
# Out:
# array([7.23675268])

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,0.0453737*x_test + 7.23675268, 'r')
plt.show()

# %%
print("Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Accuracy:  60.46843491214396
